# %%
from phoenix import distributionfunction, sampling, actions_to_phase_space
from phoenix.potentials import miyamoto_nagai_potential, plummer_potential
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
# Out:
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:10: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:38: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:44: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:50: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:56: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:86: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:114: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:119: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:125: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:131: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:138: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:172: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:185: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_spheroidal.py:10: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped

# %%
params = {
    "R0": 8.0, # for actions to phase space
    "N0_spheroid": 1e6,
    "J0_spheroid": 1000.0,
    "Gamma_spheroid": 2.5,
    "Beta_spheroid": 3.5,
}

# %%
envelope_max = 3.0
n_candidates = 250_000
key = jax.random.PRNGKey(42)

# %%
Phi_spheroid = plummer_potential


theta_spheroid = jnp.array([1e12, 10.0]) # (M, a) z.B. für Plummer

# %%
#Generate candidate actions
from phoenix.distributionfunctions_spheroidal import f_double_power_law as df_spheroid
candidates, samples, soft_weights = sampling.sample_df_potential_single(df_spheroid, key, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, tau=0.01)
print("Number of candidate actions:", samples.shape[0])
# Out:
# Number of candidate actions: 250000

# %%
#Visualize the distribution of candidate actions
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
axs[0].hist(samples[:, 0], bins=50, weights=soft_weights)
axs[0].set_xlabel(r"$J_r$")
axs[1].hist(samples[:, 1], bins=50, weights=soft_weights)
axs[1].set_xlabel(r"$J_z$")
axs[2].hist(samples[:, 2], bins=50, weights=soft_weights)
axs[2].set_xlabel(r"$L_z$")
plt.tight_layout()
plt.show()

# %%
#Map the candidate actions to phase-space coordinates
phase_space_coords = actions_to_phase_space.map_actions_to_phase_space(samples, params, key, Phi_spheroid, theta_spheroid)

x = phase_space_coords[:, 0]
y = phase_space_coords[:, 1]
z = phase_space_coords[:, 2]

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.hist2d(x, y, bins=50, cmap="viridis", norm=colors.LogNorm(), cmin=1, weights=soft_weights)
plt.xlabel('x [kpc]')
plt.ylabel('y [kpc]')
plt.axis('equal')
plt.subplot(132)
plt.hist2d(x, z, bins=50, cmap="viridis", norm=colors.LogNorm(), cmin=1, weights=soft_weights)
plt.xlabel('x [kpc]')
plt.ylabel('z [kpc]')
plt.axis('equal')
plt.subplot(133)
plt.hist2d(y, z, bins=50, cmap="viridis", norm=colors.LogNorm(), cmin=1, weights=soft_weights)
plt.xlabel('y [kpc]')
plt.ylabel('z [kpc]')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
v_x = phase_space_coords[:, 3]
v_y = phase_space_coords[:, 4]
v_z = phase_space_coords[:, 5]

R = jnp.sqrt(x**2 + y**2)
mask = R > 0.0
v_x_masked = v_x[mask]
v_y_masked = v_y[mask]
v_z_masked = v_z[mask]

plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.hist(v_x_masked, bins=50, weights=soft_weights[mask])#, range=(-500, 500))
plt.xlabel(r"$v_\text{x}$ (km/s)")
plt.ylabel("Number of stars")


plt.subplot(1,3,2)
plt.hist(v_y_masked, bins=50, weights=soft_weights[mask])
plt.xlabel(r"$v_\text{y}$ (km/s)")
plt.ylabel("Number of stars")

plt.subplot(1,3,3)
plt.hist(v_z_masked, bins=50, weights=soft_weights[mask])
plt.xlabel(r"$v_\text{z}$ (km/s)")
plt.ylabel("Number of stars")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

num_bins_x = 40
num_bins_z = 40 

# Example: x, z, v_y are 1D arrays of particle positions and velocities
# Define bin edges
x_bins = np.linspace(x.min(), x.max(), num_bins_x + 1)
z_bins = np.linspace(z.min(), z.max(), num_bins_z + 1)

# Digitize positions to bin indices
x_idx = np.digitize(x, x_bins) - 1
z_idx = np.digitize(z, z_bins) - 1

# Initialize array for mean v_y
mean_vy = np.full((num_bins_x, num_bins_z), np.nan)

# Calculate mean v_y for each bin
for i in range(num_bins_x):
    for j in range(num_bins_z):
        mask = (x_idx == i) & (z_idx == j)
        if np.any(mask):
            mean_vy[i, j] = np.average(v_y[mask], weights=soft_weights[mask])

# Plot with imshow
plt.imshow(mean_vy.T, origin='lower', aspect='auto',
           extent=[x_bins[0], x_bins[-1], z_bins[0], z_bins[-1]],
           cmap='RdBu') #, vmin=-10000, vmax=10000)#, vmin = np.percentile(mean_vy, 0.001), vmax = np.percentile(mean_vy, 99.999))
plt.xlabel('x')
plt.ylabel('z')
plt.title('Mean $v_y$ (Line-of-Sight Velocity)')
plt.colorbar(label='Mean $v_y$')
#plt.axis('equal')
plt.show()

# %%
import jax
import jax.numpy as jnp

def compute_laplacian_on_grid(potential, theta, r_bins, z_bins):
    """
    Computes nabla^2 Phi (Laplacian) on the centers of the R-Z bins.
    """
    
    # 1. Define the Laplacian for a SINGLE point (x, y, z)
    def potential_wrapper(x, y, z):
        return potential(x, y, z, *theta)

    def laplacian_fn(x, y, z):
        # jax.hessian returns a 3x3 matrix of second derivatives
        # argnums=(0, 1, 2) makes it return a nested tuple structure relative to x,y,z
        # However, it's easier to treat input as a vector for Hessian logic,
        # but since our function takes scalars, we can just sum unmixed 2nd derivatives.
        
        # Method A: Direct curvature calculation (faster/simpler than full Hessian)
        # We use simple nested grad or specific derivative operators
        d2dx2 = jax.grad(lambda x_: jax.grad(potential_wrapper, argnums=0)(x_, y, z))(x)
        d2dy2 = jax.grad(lambda y_: jax.grad(potential_wrapper, argnums=1)(x, y_, z))(y)
        d2dz2 = jax.grad(lambda z_: jax.grad(potential_wrapper, argnums=2)(x, y, z_))(z)
        
        return d2dx2 + d2dy2 + d2dz2

    # 2. Vectorize the Laplacian function
    # Maps over inputs x, y, z
    laplacian_vmap = jax.vmap(laplacian_fn, in_axes=(0, 0, 0))

    # 3. Setup Grid (Bin Centers)
    r_centers = 0.5 * (r_bins[:-1] + r_bins[1:])
    z_centers = 0.5 * (z_bins[:-1] + z_bins[1:])
    
    # Create Meshgrid (indexing='ij' matches density shape)
    R_grid, Z_grid = jnp.meshgrid(r_centers, z_centers, indexing='ij')

    # 4. Convert R-Z to Cartesian X-Y-Z
    # We evaluate at y=0, so x=R
    X_flat = R_grid.flatten()
    Y_flat = jnp.zeros_like(X_flat)
    Z_flat = Z_grid.flatten()

    # 5. Compute
    laplacian_flat = laplacian_vmap(X_flat, Y_flat, Z_flat)
    
    # Reshape back to (N_r, N_z)
    laplacian_grid = laplacian_flat.reshape(R_grid.shape)
    
    return laplacian_grid

# %%
r_bins = jnp.linspace(0.1, 10, 100) # Avoid 0 if potential has singularity at origin
z_bins = jnp.linspace(-5, 5, 100)

# JIT Compile
#jit_laplacian = jax.jit(compute_laplacian_on_grid)

# Run
#nabla2_Phi = jit_laplacian(r_bins, z_bins, theta)

nabla2_Phi = compute_laplacian_on_grid(Phi_spheroid, theta_spheroid, r_bins, z_bins)

print("Laplacian shape:", nabla2_Phi.shape)
# Out:
# Laplacian shape: (99, 99)

# %%
plt.imshow(nabla2_Phi.T, origin='lower', aspect='auto',
           extent=[jnp.min(r_bins), jnp.max(r_bins), jnp.min(z_bins), jnp.max(z_bins)], cmap='viridis', norm=colors.LogNorm())
plt.colorbar(label='Density')
plt.xlabel('r [kpc]')
plt.ylabel('z [kpc]')
plt.title('Laplacian of Potential in r-z Plane')
plt.show()

# %%
import jax
import jax.numpy as jnp

def calculate_density_cic(x, y, z, weights, r_bins, z_bins):
    """
    Computes physical density rho(R, Z) using Cloud-in-Cell (CIC) interpolation.
    
    Args:
        x, y, z: Particle coordinates (Arrays of shape (N,))
        weights: Particle mass/weights (Array of shape (N,))
        r_bins: 1D array of bin edges for R
        z_bins: 1D array of bin edges for Z
        
    Returns:
        density_map: 2D array (shape [n_r, n_z]) of physical density.
    """
    # --- 1. Grid Properties ---
    r = jnp.sqrt(x**2 + y**2)
    dr = r_bins[1] - r_bins[0]
    dz = z_bins[1] - z_bins[0]
    
    n_r = len(r_bins) - 1
    n_z = len(z_bins) - 1
    
    r_min, z_min = r_bins[0], z_bins[0]

    # --- 2. Locate Particles in Grid (Continuous Index) ---
    # r_idx_float = 5.5 means the particle is exactly between bin 5 and 6
    r_idx_float = (r - r_min) / dr
    z_idx_float = (z - z_min) / dz

    # --- 3. Compute Interpolation Weights (Bilinear) ---
    # Determine the lower-left corner index
    r_idx = jnp.floor(r_idx_float).astype(jnp.int32)
    z_idx = jnp.floor(z_idx_float).astype(jnp.int32)

    # Clip indices to ensure we don't access out of bounds
    # We stop at n-2 so that "idx+1" is still a valid bin (n-1)
    r_idx = jnp.clip(r_idx, 0, n_r - 2)
    z_idx = jnp.clip(z_idx, 0, n_z - 2)

    # Fractional distance to the next bin center (0.0 to 1.0)
    rw = r_idx_float - r_idx
    zw = z_idx_float - z_idx
    
    # Clip fractions (handles particles strictly outside the grid)
    rw = jnp.clip(rw, 0.0, 1.0)
    zw = jnp.clip(zw, 0.0, 1.0)

    # Distribute mass to the 4 nearest grid neighbors
    # (1-w) is "left/bottom" contribution, (w) is "right/top" contribution
    w00 = (1 - rw) * (1 - zw) * weights # Bottom-Left
    w10 = (rw)     * (1 - zw) * weights # Bottom-Right
    w01 = (1 - rw) * (zw)     * weights # Top-Left
    w11 = (rw)     * (zw)     * weights # Top-Right

    # --- 4. Scatter Mass to Grid (High Speed Accumulation) ---
    # We flatten the grid to use simple scatter operations
    # Index mapping: flat_idx = r * n_z + z
    grid_flat = jnp.zeros(n_r * n_z)
    
    def get_flat_idx(ri, zi):
        return ri * n_z + zi

    # Add mass to the 4 corners
    grid_flat = grid_flat.at[get_flat_idx(r_idx,     z_idx)].add(w00)
    grid_flat = grid_flat.at[get_flat_idx(r_idx + 1, z_idx)].add(w10)
    grid_flat = grid_flat.at[get_flat_idx(r_idx,     z_idx + 1)].add(w01)
    grid_flat = grid_flat.at[get_flat_idx(r_idx + 1, z_idx + 1)].add(w11)

    # Reshape back to 2D (Mass Map)
    mass_map = grid_flat.reshape((n_r, n_z))

    # --- 5. Convert Mass to Density (Volume Normalization) ---
    # We need the volume of every bin (ring).
    # Since we used uniform grid spacing earlier (dr, dz), we can compute bin centers.
    # But using the exact analytical volume of the ring is safer near R=0.
    
    # Volume of ring i = Pi * (R_outer^2 - R_inner^2) * dZ
    # R_outer = r_bins[i+1], R_inner = r_bins[i]
    # This creates a 1D array of volumes for the R-bins
    r_volumes = jnp.pi * (r_bins[1:]**2 - r_bins[:-1]**2) * dz
    
    # Reshape to (n_r, 1) so we can divide the 2D map
    # (JAX broadcasts the R-volume across all Z-bins, which is correct for cylinders)
    bin_volumes = r_volumes[:, None] 
    
    # Avoid division by zero (though volume shouldn't be zero unless bin width is 0)
    density_map = mass_map / jnp.maximum(bin_volumes, 1e-10)
    valid_mask = (mass_map > 0).astype(jnp.float32)

    return density_map, valid_mask

# %%
# Old
# density = calculate_density_map_laxscan(...)

# New
density, mask = calculate_density_cic(x, y, z, soft_weights, r_bins, z_bins)

# %%
plt.imshow(density.T, origin='lower', aspect='auto',
           extent=[jnp.min(r_bins), jnp.max(r_bins), jnp.min(z_bins), jnp.max(z_bins)], cmap='viridis', norm=colors.LogNorm())
plt.colorbar(label='Density (KDE)')
plt.xlabel('r [kpc]')
plt.ylabel('z [kpc]')
plt.title('KDE Density Distribution in r-z Plane')
plt.show()

# %%
G=4.300917e-6 # in (km/s)^2 * kpc / Msun

lossplane = (4*jnp.pi*G*density - nabla2_Phi)

plt.imshow(lossplane.T, origin='lower', aspect='auto',
           extent=[jnp.min(r_bins), jnp.max(r_bins), jnp.min(z_bins), jnp.max(z_bins)], cmap='viridis')
plt.colorbar(label='loss')
plt.xlabel('r [kpc]')
plt.ylabel('z [kpc]')
plt.title('Loss Distribution in r-z Plane')
plt.show()

# %%
from functools import partial
import jax

@partial(jax.jit, static_argnames=['df_spheroid',"Phi_spheroid", 'n_candidates', 'envelope_max'])
def loss_fn_complete(df_spheroid, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, r_bins, z_bins, key_potential):

    candidates, samples, soft_weights = sampling.sample_df_potential_single(df_spheroid, key_potential, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, tau=0.01)
    phase_space_coords = actions_to_phase_space.map_actions_to_phase_space(samples, params, key_potential, Phi_spheroid, theta_spheroid)
    x = phase_space_coords[:, 0]
    y = phase_space_coords[:, 1]
    z = phase_space_coords[:, 2]

    nabla2_Phi = compute_laplacian_on_grid(Phi_spheroid, theta_spheroid, r_bins, z_bins)

    # 1. Compute the KDE density
    density, mask = calculate_density_cic(
        x, y, z, soft_weights, r_bins, z_bins,
    )
    diff = (4*jnp.pi*G*density - nabla2_Phi)
    weighted_sq_error = (diff**2) * mask
    # 2. Define a scalar loss (e.g., Mean Squared Error or L2 loss)
    # The sum of squared differences is a common, differentiable loss.
    loss = jnp.sum(weighted_sq_error)
    
    return loss

#loss_fn_complete = jax.jit(_loss_fn_complete_uncompiled, static_argnums=(0, 2))

# %%
# --- Gradient Calculation ---

# 1. Define the gradient function targeting theta_spheroid (index 3)
#grad_theta_fn = jax.grad(loss_fn_complete, argnums=3)

#@jax.jit
def loss_wrapper(params, theta_spheroid, r_bins, z_bins, key):
    return loss_fn_complete(
        df_spheroid=df_spheroid,       # Static (Global variable)
        params=params,                 # Array/Dict (Argument)
        Phi_spheroid=Phi_spheroid,     # Static (Global variable)
        theta_spheroid=theta_spheroid, # Array (Argument - Target of Grad)
        n_candidates=n_candidates,     # Static (Global variable)
        envelope_max=envelope_max,     # Static (Global variable)
        r_bins=r_bins,                 # Array
        z_bins=z_bins,                 # Array
        key_potential=key              # Array
    )

# Index 0: params
# Index 1: theta_spheroid  <-- We want this one
grad_theta_fn = jax.grad(loss_wrapper, argnums=1)

# 2. Define the static key (required for jitter)
static_key = jax.random.PRNGKey(42)

# 3. Compute the gradient
# You need to pass all arguments, including the static key
theta_grad = grad_theta_fn(
    params, 
    theta_spheroid, 
    r_bins, 
    z_bins, 
    key
)

print(f"Gradient w.r.t. theta_spheroid: {theta_grad}")
print(f"Maximum gradient magnitude for theta_spheroid: {jnp.max(jnp.abs(theta_grad))}")
# Out:
# Gradient w.r.t. theta_spheroid: [ 4.67548072e-01 -1.23808236e+11]
# Maximum gradient magnitude for theta_spheroid: 123808235520.0

# %%
theta_grad = grad_theta_fn(
    params, 
    theta_spheroid, 
    r_bins, 
    z_bins, 
    key
)

print(f"Gradient w.r.t. theta_spheroid: {theta_grad}")
print(f"Maximum gradient magnitude for theta_spheroid: {jnp.max(jnp.abs(theta_grad))}")
# Out:
# Gradient w.r.t. theta_spheroid: [ 4.67548072e-01 -1.23808236e+11]
# Maximum gradient magnitude for theta_spheroid: 123808235520.0

# %%
# --- Gradient Calculation ---

# 1. Define the gradient function targeting theta_spheroid (index 1)
grad_param_fn = jax.grad(loss_fn_complete, argnums=1)

# 2. Define the static key (required for jitter)
static_key = jax.random.PRNGKey(42)

# 3. Compute the gradient
# You need to pass all arguments, including the static key
param_grad = grad_param_fn(
    df_spheroid, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, r_bins, z_bins, key
)

print(f"Gradient w.r.t. params: {param_grad}")
# Out:
# Gradient w.r.t. params: {'Beta_spheroid': Array(2.4800053, dtype=float32, weak_type=True), 'Gamma_spheroid': Array(-19.931957, dtype=float32, weak_type=True), 'J0_spheroid': Array(0.003331, dtype=float32, weak_type=True), 'N0_spheroid': Array(-1.0888552e-05, dtype=float32, weak_type=True), 'R0': Array(1.2444825e-09, dtype=float32, weak_type=True)}

# %%
def loss_fn_complete_adam(df_spheroid, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, r_bins, z_bins, key_potential):
    
    #theta_rescaled = theta_spheroid
    # Rescale index 0: theta_rescaled = theta_rescaled.at[0].set(new_value)
    #theta_rescaled = theta_rescaled.at[0].set(theta_spheroid[0] * 1e12)
    # Rescale index 1: (Use the new array from the previous step)
    #theta_rescaled = theta_rescaled.at[1].set(theta_spheroid[1] * 1e4)
    #scaling_vector = jnp.array([1e12, 1e4]) 
    #theta_rescaled = theta_spheroid * scaling_vector

    candidates, samples, soft_weights = sampling.sample_df_potential_single(df_spheroid, key_potential, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, tau=0.01)
    phase_space_coords = actions_to_phase_space.map_actions_to_phase_space(samples, params, key_potential, Phi_spheroid, theta_spheroid)
    x = phase_space_coords[:, 0]
    y = phase_space_coords[:, 1]
    z = phase_space_coords[:, 2]

    nabla2_Phi = compute_laplacian_on_grid(Phi_spheroid, theta_spheroid, r_bins, z_bins)

    # 1. Compute the KDE density
    density = calculate_density_map_laxscan(
        x, y, z, soft_weights, r_bins, z_bins, bandwidth=5.0
    )
    #diff = (4*jnp.pi*G_kpc_Msun*density - nabla2_Phi)
    diff = (4*jnp.pi*G*density - nabla2_Phi)
    
    # Gewichtung
    r_centers = 0.5 * (r_bins[:-1] + r_bins[1:])
    z_centers = 0.5 * (z_bins[:-1] + z_bins[1:])
    R_grid, Z_grid = jnp.meshgrid(r_centers, z_centers, indexing='ij')

    # Fokus auf Zentrum: r=0, z=0
    # Die Vorfaktoren (2 bei r) bestimmen, wie "schmal" der Fokus ist
    #weights = jnp.exp(-10 * R_grid**2) * jnp.exp(-Z_grid**2)
    #loss
    
    loss = jnp.nansum((diff)**2)#*weights)
    
    return loss

# %%
import jax
import jax.numpy as jnp
import optax

def adam_optimizer(loss_fn_complete, df_spheroid, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, r_bins, z_bins, key_potential, tol=1e-3, max_iter=1000):
    # Initialize optimizer
    optimizer = optax.adam(learning_rate=1e-1)
    #opt_state = optimizer.init(theta_spheroid)
    #log_theta = jnp.log(theta_spheroid)
    opt_state = optimizer.init(theta_spheroid)#log_theta)

    theta_history = []
    loss_history = []

    for iteration in range(max_iter):
        # Compute gradients
        #actual_theta = jnp.exp(log_theta)
        loss, grads  = jax.value_and_grad(lambda p: loss_fn_complete(df_spheroid, params, Phi_spheroid, p, n_candidates, envelope_max, r_bins, z_bins, key_potential))(theta_spheroid)
        loss_history.append(loss)
        theta_history.append(theta_spheroid)
        # Update parameters
        updates, opt_state = optimizer.update(grads, opt_state)
        #log_theta = optax.apply_updates(log_theta, updates)
        theta_spheroid = optax.apply_updates(theta_spheroid, updates)

        if optax.global_norm(updates) < tol:
            print(f"Converged after {iteration} iterations.")
            break

    return theta_spheroid, jnp.array(theta_history), jnp.array(loss_history)

# %%
#theta_spheroid_init = jnp.array([1.0, 1.0])  # Initial guess for (M, a)
optimzed_theta, theta_hist, loss_hist = adam_optimizer(
    loss_fn_complete_adam, df_spheroid, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, r_bins, z_bins, key,
    tol=1e-3, max_iter=100
)
# Out:
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main()
#
# File <frozen runpy>:88, in _run_code()
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/ipykernel/kernelapp.py:758, in start()
#     757 try:
# --> 758     self.io_loop.start()
#     759 except KeyboardInterrupt:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/tornado/platform/asyncio.py:211, in start()
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File ~/.conda/envs/phoenix/lib/python3.12/asyncio/base_events.py:645, in run_forever()
#     644 while True:
# --> 645     self._run_once()
#     646     if self._stopping:
#
# File ~/.conda/envs/phoenix/lib/python3.12/asyncio/base_events.py:1999, in _run_once()
#    1998     else:
# -> 1999         handle._run()
#    2000 handle = None
#
# File ~/.conda/envs/phoenix/lib/python3.12/asyncio/events.py:88, in _run()
#      87 try:
# ---> 88     self._context.run(self._callback, *self._args)
#      89 except (SystemExit, KeyboardInterrupt):
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/ipykernel/kernelbase.py:614, in shell_main()
#     613 async with asyncio_lock:
# --> 614     await self.dispatch_shell(msg, subshell_id=subshell_id)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/ipykernel/kernelbase.py:471, in dispatch_shell()
#     470     if inspect.isawaitable(result):
# --> 471         await result
#     472 except Exception:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/ipykernel/ipkernel.py:366, in execute_request()
#     365 """Override for cell output - cell reconciliation."""
# --> 366 await super().execute_request(stream, ident, parent)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/ipykernel/kernelbase.py:827, in execute_request()
#     826 if inspect.isawaitable(reply_content):
# --> 827     reply_content = await reply_content
#     828 else:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/ipykernel/ipkernel.py:458, in do_execute()
#     457 if accepts_params["cell_id"]:
# --> 458     res = shell.run_cell(
#     459         code,
#     460         store_history=store_history,
#     461         silent=silent,
#     462         cell_id=cell_id,
#     463     )
#     464 else:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/ipykernel/zmqshell.py:663, in run_cell()
#     662 self._last_traceback = None
# --> 663 return super().run_cell(*args, **kwargs)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3116, in run_cell()
#    3115 try:
# -> 3116     result = self._run_cell(
#    3117         raw_cell, store_history, silent, shell_futures, cell_id
#    3118     )
#    3119 finally:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3171, in _run_cell()
#    3170 try:
# -> 3171     result = runner(coro)
#    3172 except BaseException as e:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3394, in run_cell_async()
#    3391 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3394 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3395        interactivity=interactivity, compiler=compiler, result=result)
#    3397 self.last_execution_succeeded = not has_raised
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3639, in run_ast_nodes()
#    3638     asy = compare(code)
# -> 3639 if await self.run_code(code, result, async_=asy):
#    3640     return True
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3699, in run_code()
#    3698     else:
# -> 3699         exec(code_obj, self.user_global_ns, self.user_ns)
#    3700 finally:
#    3701     # Reset our crash handler in place
#
# Cell In[30], line 2
#       1 #theta_spheroid_init = jnp.array([1.0, 1.0])  # Initial guess for (M, a)
# ----> 2 optimzed_theta, theta_hist, loss_hist = adam_optimizer(
#       3     loss_fn_complete_adam, df_spheroid, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, r_bins, z_bins, key,
#       4     tol=1e-3, max_iter=100
#       5 )
#
# Cell In[29], line 18, in adam_optimizer()
#      15 for iteration in range(max_iter):
#      16     # Compute gradients
#      17     #actual_theta = jnp.exp(log_theta)
# ---> 18     loss, grads  = jax.value_and_grad(lambda p: loss_fn_complete(df_spheroid, params, Phi_spheroid, p, n_candidates, envelope_max, r_bins, z_bins, key_potential))(theta_spheroid)
#      19     loss_history.append(loss)
#
# Cell In[29], line 18, in adam_optimizer.<locals>.<lambda>()
#      15 for iteration in range(max_iter):
#      16     # Compute gradients
#      17     #actual_theta = jnp.exp(log_theta)
# ---> 18     loss, grads  = jax.value_and_grad(lambda p: loss_fn_complete(df_spheroid, params, Phi_spheroid, p, n_candidates, envelope_max, r_bins, z_bins, key_potential))(theta_spheroid)
#      19     loss_history.append(loss)
#
# Cell In[28], line 17, in loss_fn_complete_adam()
#      15 z = phase_space_coords[:, 2]
# ---> 17 nabla2_Phi = compute_laplacian_on_grid(Phi_spheroid, theta_spheroid, r_bins, z_bins)
#      19 # 1. Compute the KDE density
#
# Cell In[12], line 45, in compute_laplacian_on_grid()
#      44 # 5. Compute
# ---> 45 laplacian_flat = laplacian_vmap(X_flat, Y_flat, Z_flat)
#      47 # Reshape back to (N_r, N_z)
#
# Cell In[12], line 23, in laplacian_fn()
#      22 d2dy2 = jax.grad(lambda y_: jax.grad(potential_wrapper, argnums=1)(x, y_, z))(y)
# ---> 23 d2dz2 = jax.grad(lambda z_: jax.grad(potential_wrapper, argnums=2)(x, y, z_))(z)
#      25 return d2dx2 + d2dy2 + d2dz2
#
# Cell In[12], line 23, in compute_laplacian_on_grid.<locals>.laplacian_fn.<locals>.<lambda>()
#      22 d2dy2 = jax.grad(lambda y_: jax.grad(potential_wrapper, argnums=1)(x, y_, z))(y)
# ---> 23 d2dz2 = jax.grad(lambda z_: jax.grad(potential_wrapper, argnums=2)(x, y, z_))(z)
#      25 return d2dx2 + d2dy2 + d2dz2
#
# Cell In[12], line 11, in potential_wrapper()
#      10 def potential_wrapper(x, y, z):
# ---> 11     return potential(x, y, z, *theta)
#
# File ~/phoenix/phoenix/potentials.py:204, in plummer_potential()
#     203 r2 = x**2 + y**2 + z**2
# --> 204 return -G*M / jnp.sqrt(a**2 + r2)
#
# JaxStackTraceBeforeTransformation: KeyboardInterrupt
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 #theta_spheroid_init = jnp.array([1.0, 1.0])  # Initial guess for (M, a)
# ----> 2 optimzed_theta, theta_hist, loss_hist = adam_optimizer(
#       3     loss_fn_complete_adam, df_spheroid, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, r_bins, z_bins, key,
#       4     tol=1e-3, max_iter=100
#       5 )
#
# Cell In[29], line 18, in adam_optimizer(loss_fn_complete, df_spheroid, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, r_bins, z_bins, key_potential, tol, max_iter)
#      13 loss_history = []
#      15 for iteration in range(max_iter):
#      16     # Compute gradients
#      17     #actual_theta = jnp.exp(log_theta)
# ---> 18     loss, grads  = jax.value_and_grad(lambda p: loss_fn_complete(df_spheroid, params, Phi_spheroid, p, n_candidates, envelope_max, r_bins, z_bins, key_potential))(theta_spheroid)
#      19     loss_history.append(loss)
#      20     theta_history.append(theta_spheroid)
#
#     [... skipping hidden 1 frame]
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/api.py:552, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     550 _check_scalar(ans)
#     551 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 552 g = vjp_py(lax_internal._one_vjp(ans))
#     553 g = g[0] if isinstance(argnums, int) else g
#     554 if not has_aux:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/api.py:2478, in VJP.__call__(self, out_ct, *extra_args)
#    2476   name, *_ = self.jaxpr.debug_info.func_src_info.split(' ')
#    2477   raise TypeError(_vjp_too_many_args(name, len(extra_args)))
# -> 2478 return self.fun(self.in_tree, self.out_tree, self.args_res,
#    2479                 self.opaque_residuals)(out_ct)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/tree_util.py:485, in _HashableCallableShim.__call__(self, *args, **kw)
#     484 def __call__(self, *args, **kw):
# --> 485   return self.fun(*args, **kw)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/api.py:2396, in _vjp3_bwd(in_tree, out_tree, out_known, jaxpr, out_primal_avals, residuals, maybe_refs, out_ct)
#    2394 _vjp_check_ct_avals(cts_flat, out_primal_avals)
#    2395 cts_flat = [ct for ct, k in zip(cts_flat, out_known) if not k]
# -> 2396 ad.backward_pass3(jaxpr, True, residuals, maybe_refs, cts_flat)
#    2397 arg_cts = [x.freeze() if isinstance(x, ad.ValAccum) else GradRef()
#    2398            for x in maybe_refs]
#    2399 arg_cts = map(ad.instantiate_zeros, arg_cts)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:558, in backward_pass3(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     556 for x, ct in zip(primals, cts_out):
#     557   if isinstance(x, GradAccum):
# --> 558     x.accum(ct)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:610, in ValAccum.accum(self, x)
#     608 def accum(self, x):
#     609   if x is not None:
# --> 610     self.val = add_tangents(self.val, x)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:1266, in add_tangents(x, y)
#    1264   return x
#    1265 else:
# -> 1266   return add_jaxvals(x, y)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/ad_util.py:38, in add_jaxvals(x, y)
#      36   return ty.vspace_add(x, y)
#      37 x, y = core.standard_insert_pvary(x, y)
# ---> 38 return add_jaxvals_p.bind(x, y)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:632, in Primitive.bind(self, *args, **params)
#     630 def bind(self, *args, **params):
#     631   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 632   return self._true_bind(*args, **params)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:648, in Primitive._true_bind(self, *args, **params)
#     646 trace_ctx.set_trace(eval_trace)
#     647 try:
# --> 648   return self.bind_with_trace(prev_trace, args, params)
#     649 finally:
#     650   trace_ctx.set_trace(prev_trace)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:660, in Primitive.bind_with_trace(self, trace, args, params)
#     658     with set_current_trace(trace):
#     659       return self.to_lojax(*args, **params)  # type: ignore
# --> 660   return trace.process_primitive(self, args, params)
#     661 trace.process_primitive(self, args, params)  # may raise lojax error
#     662 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:1189, in EvalTrace.process_primitive(self, primitive, args, params)
#    1187 args = map(full_lower, args)
#    1188 check_eval_args(args)
# -> 1189 return primitive.impl(*args, **params)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/ad_util.py:45, in add_impl(x, y)
#      43 @add_jaxvals_p.def_impl
#      44 def add_impl(x, y):
# ---> 45   return raw_jaxval_adders[type(x)](x, y)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/lax/lax.py:3932, in _add_arrays(x, y)
#    3929 if (isinstance(a := core.get_aval(x), ShapedArray) and
#    3930     dtypes.issubdtype(a.dtype, dtypes.extended)):
#    3931   return dtype._rules.add(dtype, x, y)  # pytype: disable=attribute-error
# -> 3932 return add(x, y)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/lax/lax.py:1198, in add(x, y)
#    1178 r"""Elementwise addition: :math:`x + y`.
#    1179
#    1180 This function lowers directly to the `stablehlo.add`_ operation.
#    (...)   1195 .. _stablehlo.add: https://openxla.org/stablehlo/spec#add
#    1196 """
#    1197 x, y = core.standard_insert_pvary(x, y)
# -> 1198 return add_p.bind(x, y)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:632, in Primitive.bind(self, *args, **params)
#     630 def bind(self, *args, **params):
#     631   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 632   return self._true_bind(*args, **params)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:648, in Primitive._true_bind(self, *args, **params)
#     646 trace_ctx.set_trace(eval_trace)
#     647 try:
# --> 648   return self.bind_with_trace(prev_trace, args, params)
#     649 finally:
#     650   trace_ctx.set_trace(prev_trace)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:660, in Primitive.bind_with_trace(self, trace, args, params)
#     658     with set_current_trace(trace):
#     659       return self.to_lojax(*args, **params)  # type: ignore
# --> 660   return trace.process_primitive(self, args, params)
#     661 trace.process_primitive(self, args, params)  # may raise lojax error
#     662 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:1189, in EvalTrace.process_primitive(self, primitive, args, params)
#    1187 args = map(full_lower, args)
#    1188 check_eval_args(args)
# -> 1189 return primitive.impl(*args, **params)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/dispatch.py:92, in apply_primitive(prim, *args, **params)
#      90 prev = config.disable_jit.swap_local(False)
#      91 try:
# ---> 92   outs = fun(*args)
#      93 finally:
#      94   config.disable_jit.set_local(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:264, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     259 if config.no_tracing.value:
#     260   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     261                      "`jit`, but 'no_tracing' is set")
#     263 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 264  executable, pgle_profiler, const_args) = _python_pjit_helper(
#     265      fun, jit_info, *args, **kwargs)
#     267 maybe_fastpath_data = _get_fastpath_data(
#     268     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     269     jit_info.abstracted_axes, pgle_profiler,
#     270     const_args)
#     272 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:146, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     144   args_flat = map(core.full_lower, args_flat)
#     145   core.check_eval_args(args_flat)
# --> 146   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     147       *args_flat, **p.params)
#     148 else:
#     149   out_flat = jit_p.bind(*args_flat, **p.params)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:1642, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1634     fingerprint = fingerprint.hex()
#    1635   distributed_debug_log(("Running pjit'd function", name),
#    1636                         ("in_shardings", in_shardings),
#    1637                         ("out_shardings", out_shardings),
#    (...)   1640                         ("abstract args", map(core.abstractify, args)),
#    1641                         ("fingerprint", fingerprint))
# -> 1642 return (compiled.unsafe_call(*computation.const_args, *args),
#    1643         compiled, pgle_profiler, computation.const_args)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/profiler.py:359, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     356 @wraps(func)
#     357 def wrapper(*args, **kwargs):
#     358   with TraceAnnotation(name, **decorator_kwargs):
# --> 359     return func(*args, **kwargs)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1378, in ExecuteReplicated.__call__(self, *args)
#    1376   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1377 else:
# -> 1378   results = self.xla_executable.execute_sharded(input_bufs)
#    1380 if dispatch.needs_check_special():
#    1381   out_arrays = results.disassemble_into_single_device_arrays()
#
# KeyboardInterrupt:

# %%
print(loss_hist)
# Out:
# [4.9976218e+09 4.7866092e+09 4.5866348e+09 4.3972250e+09 4.2178982e+09
#  4.0481905e+09 3.8876291e+09 3.7357683e+09 3.5921610e+09 3.4563786e+09
#  3.3279959e+09 3.2066179e+09 3.0918469e+09 2.9833252e+09 2.8806881e+09
#  2.7835924e+09 2.6917233e+09 2.6047718e+09 2.5224438e+09 2.4444690e+09
#  2.3705848e+09 2.3005420e+09 2.2341153e+09 2.1710802e+09 2.1112365e+09
#  2.0543921e+09 2.0003597e+09 1.9489774e+09 1.9000803e+09 1.8535204e+09
#  1.8091583e+09 1.7668621e+09 1.7265100e+09 1.6879876e+09 1.6511843e+09
#  1.6160019e+09 1.5823460e+09 1.5501284e+09 1.5192663e+09 1.4896814e+09
#  1.4613029e+09 1.4340641e+09 1.4078995e+09 1.3827500e+09 1.3585601e+09
#  1.3352801e+09 1.3128588e+09 1.2912543e+09 1.2704191e+09 1.2503151e+09
#  1.2309051e+09 1.2121545e+09 1.1940285e+09 1.1764969e+09 1.1595313e+09
#  1.1431030e+09 1.1271869e+09 1.1117581e+09 1.0967936e+09 1.0822742e+09
#  1.0681773e+09 1.0544837e+09 1.0411779e+09 1.0282402e+09 1.0156577e+09
#  1.0034124e+09 9.9149139e+08 9.7988134e+08 9.6856870e+08 9.5754227e+08
#  9.4679078e+08 9.3630221e+08 9.2606714e+08 9.1607725e+08 9.0632166e+08
#  8.9679110e+08 8.8747962e+08 8.7837651e+08 8.6947706e+08 8.6077203e+08
#  8.5225530e+08 8.4391981e+08 8.3576134e+08 8.2777318e+08 8.1994816e+08
#  8.1228326e+08 8.0477222e+08 7.9741011e+08 7.9019181e+08 7.8311398e+08
#  7.7617235e+08 7.6936186e+08 7.6267898e+08 7.5612077e+08 7.4968230e+08
#  7.4336058e+08 7.3715315e+08 7.3105587e+08 7.2506509e+08 7.1917978e+08]

# %%
plt.plot(loss_hist)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss History during Adam Optimization')
plt.show()

# %%
print(theta_hist[:,0])
# Out:
# [1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12
#  1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12
#  1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12
#  1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12
#  1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12
#  1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12
#  1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12
#  1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12
#  1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12
#  1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12 1.e+12]

# %%
plt.figure(figsize=(10, 4))

# Plot for theta_hist[:, 0]
plt.subplot(1, 2, 1)
plt.plot(theta_hist[:, 0])
plt.xlabel('Iteration')
plt.ylabel('Theta Parameter Value')
plt.title('Theta Parameter 0 History')

# Plot for theta_hist[:, 1]
plt.subplot(1, 2, 2)
plt.plot(theta_hist[:, 1])
plt.xlabel('Iteration')
plt.ylabel('Theta Parameter Value')
plt.title('Theta Parameter 1 History')

plt.tight_layout()
plt.show()

# %%
print(theta_hist[-1,:])
# Out:
# [1.0000000e+12 1.5606228e+01]

# %%
def compute_optimitzed_density(df_spheroid, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, r_bins, z_bins, key_potential):
    scaling_vector = jnp.array([1e12, 1e4]) 
    theta_rescaled = theta_spheroid * scaling_vector

    candidates, samples, soft_weights = sampling.sample_df_potential_single(df_spheroid, key_potential, params, Phi_spheroid, theta_rescaled, n_candidates, envelope_max, tau=0.01)
    phase_space_coords = actions_to_phase_space.map_actions_to_phase_space(samples, params, key_potential, Phi_spheroid, theta_rescaled)
    x = phase_space_coords[:, 0]
    y = phase_space_coords[:, 1]
    z = phase_space_coords[:, 2]

    nabla2_Phi = compute_laplacian_on_grid(Phi_spheroid, theta_rescaled, r_bins, z_bins)

    # 1. Compute the KDE density
    kde_density = calculate_density_map_laxscan(
        x, y, z, soft_weights, r_bins, z_bins, bandwidth=5.0
    )
    diff = (4*jnp.pi*G*1e10 - nabla2_Phi)
    #diff = kde_density - (nabla2_Phi / (4 * jnp.pi * G))
    
    return diff, kde_density, nabla2_Phi, x, y, z

# %%
static_key = jax.random.PRNGKey(42)
final_diff, final_density_kde, final_nabla2_Phi, final_x, final_y, final_z = compute_optimitzed_density(
    df_spheroid, params, Phi_spheroid, theta_hist[-1,:], n_candidates, envelope_max, r_bins, z_bins, key
)

# %%
import matplotlib.pyplot as plt
import jax.numpy as jnp

# Create a figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot 1: Difference after Optimization
im1 = axs[0].imshow(final_diff.T, origin='lower', aspect='auto',
                     extent=[jnp.min(r_bins), jnp.max(r_bins), jnp.min(z_bins), jnp.max(z_bins)], cmap='viridis')
fig.colorbar(im1, ax=axs[0], label='Density (KDE)')
axs[0].set_xlabel('r [kpc]')
axs[0].set_ylabel('z [kpc]')
axs[0].set_title('Difference after Optimization in r-z Plane')

# Plot 2: KDE Density Distribution after Optimization
im2 = axs[1].imshow(final_density_kde.T, origin='lower', aspect='auto',
                     extent=[jnp.min(r_bins), jnp.max(r_bins), jnp.min(z_bins), jnp.max(z_bins)], cmap='viridis')
fig.colorbar(im2, ax=axs[1], label='Density (KDE)')
axs[1].set_xlabel('r [kpc]')
axs[1].set_ylabel('z [kpc]')
axs[1].set_title('KDE Density Distribution after Optimization in r-z Plane')

# Plot 3: Potential Density Distribution after Optimization
final_density_pot = final_nabla2_Phi
im3 = axs[2].imshow(final_density_pot.T, origin='lower', aspect='auto',
                     extent=[jnp.min(r_bins), jnp.max(r_bins), jnp.min(z_bins), jnp.max(z_bins)], cmap='viridis')
fig.colorbar(im3, ax=axs[2], label='Density (Potential)')
axs[2].set_xlabel('r [kpc]')
axs[2].set_ylabel('z [kpc]')
axs[2].set_title('Potential Density Distribution after Optimization in r-z Plane')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.hist2d(final_x, final_y, bins=50, cmap="viridis", norm=colors.LogNorm(), cmin=1, weights=soft_weights)
plt.xlabel('x [kpc]')
plt.ylabel('y [kpc]')
plt.axis('equal')
plt.subplot(132)
plt.hist2d(final_x, final_z, bins=50, cmap="viridis", norm=colors.LogNorm(), cmin=1, weights=soft_weights)
plt.xlabel('x [kpc]')
plt.ylabel('z [kpc]')
plt.axis('equal')
plt.subplot(133)
plt.hist2d(final_y, final_z, bins=50, cmap="viridis", norm=colors.LogNorm(), cmin=1, weights=soft_weights)
plt.xlabel('y [kpc]')
plt.ylabel('z [kpc]')
plt.axis('equal')
plt.tight_layout()
plt.show()
