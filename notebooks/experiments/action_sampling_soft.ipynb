# %%
import sys; print(sys.executable)   # should be the env where you ran pip
import phoenix; print(phoenix.__file__)
# Out:
# /Users/annalena/miniconda3/envs/phoenix/bin/python
# /Users/annalena/Documents/GitHub/phoenix/phoenix/__init__.py

# %%
from phoenix.potentials import miyamoto_nagai_potential as Phi
from phoenix.actionsampling_soft import sample_df_potential
# Out:
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:11: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:39: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:45: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:51: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:57: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:87: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:115: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:120: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:126: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:132: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:139: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:173: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/distributionfunctions.py:186: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped

# %%
# Miyamoto–Nagai params (example numbers)
M, a, b = 1e11, 6.0, 0.3

# %%
params = {
    "R0_thin": 8.0,
    "Rd_thin": 3.0,
    "Sigma0_thin": 1.0,
    "RsigR_thin": 7.0,
    "RsigZ_thin": 1.0,
    "sigmaR0_R0_thin": 60.0,
    "sigmaz0_R0_thin": 30.0,
    "L0_thin": 50.0,
    "Rinit_for_Rc_thin": 8.0,
    "R0_thick": 8.0,    
    "Rd_thick": 3.0,
    "Sigma0_thick": 1.0,
    "RsigR_thick": 7.0,
    "RsigZ_thick": 1.0,
    "sigmaR0_R0_thick": 40.0,
    "sigmaz0_R0_thick": 20.0,
    "L0_thick": 30.0,
    "Rinit_for_Rc_thick": 8.0,
}

# %%
Phi_xyz = Phi
theta = (M, a, b)

# %%
from jax import random
envelope_max = 3.0
n_candidates = 10_000_000
key = random.PRNGKey(42)

#Generate candidate actions
samples, soft_weights = sample_df_potential(key, params, Phi, theta, n_candidates, envelope_max, tau=0.01)
print("Number of candidate actions:", samples.shape[0])
# Out:
# Number of candidate actions: 10000000

# %%
print(samples)
# Out:
# [[4.0371987e-31 5.7768342e-32 3.8444214e-30]
#  [8.5923829e-12 2.3576743e-13 7.3083858e-11]
#  [5.0224665e-16 3.3312699e-16 7.8430541e-15]
#  ...
#  [6.8908017e-19 2.1339207e-19 5.7147588e-18]
#  [4.4247115e-18 2.3988720e-18 7.1041566e-17]
#  [2.5101378e+00 1.7166803e+01 2.3726079e+02]]

# %%
#Visualize the distribution of candidate actions
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 3, figsize=(15, 4))
axs[0].hist(samples[:, 0], bins=50, weights=soft_weights)
axs[0].set_xlabel(r"$J_r$")
axs[1].hist(samples[:, 1], bins=50, weights=soft_weights)
axs[1].set_xlabel(r"$J_z$")
axs[2].hist(samples[:, 2], bins=50, weights=soft_weights)
axs[2].set_xlabel(r"$L_z$")
plt.tight_layout()
plt.show()

# %%
JR = samples[:, 0]
Jz = samples[:, 1]
Jphi = samples[:, 2]

# %%
print("sampled actions (JR,Jz,Lz):")
print(JR)
print(Jz)
print(Jphi)
# Out:
# sampled actions (JR,Jz,Lz):
# [4.0371987e-31 8.5923829e-12 5.0224665e-16 ... 6.8908017e-19 4.4247115e-18
#  2.5101378e+00]
# [5.7768342e-32 2.3576743e-13 3.3312699e-16 ... 2.1339207e-19 2.3988720e-18
#  1.7166803e+01]
# [3.8444214e-30 7.3083858e-11 7.8430541e-15 ... 5.7147588e-18 7.1041566e-17
#  2.3726079e+02]

# %%
# Plot histograms of the actions
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(JR, bins=100)#, density=True)
plt.xlabel(r"$J_R$")
plt.subplot(1, 3, 2)
plt.hist(Jz, bins=100)#, density=True)
plt.xlabel(r"$J_z$")
plt.subplot(1, 3, 3)
plt.hist(Jphi, bins=100)#, density=True)
plt.xlabel(r"$J_\phi$")
plt.tight_layout()
plt.show()

# %%
import jax
from phoenix.actiontophasespace import sample_phase_from_actions
from phoenix.potentials import miyamoto_nagai_potential as Phi
# Out:
# /Users/annalena/Documents/GitHub/phoenix/phoenix/actiontophasespace.py:15: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /Users/annalena/Documents/GitHub/phoenix/phoenix/actiontophasespace.py:68: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped

# %%
# fresh RNG for angles
key = jax.random.PRNGKey(1)
x, y, z, vx, vy, vz = sample_phase_from_actions(
    key, Phi,
    JR, Jz, Jphi,
    M, a, b,              # potential params (*theta) for Phi
    Rinit_for_Rc=8.0,
)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.hexbin(x, y, gridsize=100, cmap='inferno', bins='log')
plt.xlabel('x [kpc]')
plt.ylabel('y [kpc]')
plt.axis('equal')
plt.subplot(132)
plt.hexbin(x, z, gridsize=100, cmap='inferno', bins='log')
plt.xlabel('x [kpc]')
plt.ylabel('z [kpc]')
plt.axis('equal')
plt.subplot(133)
plt.hexbin(y, z, gridsize=100, cmap='inferno', bins='log')
plt.xlabel('y [kpc]')
plt.ylabel('z [kpc]')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.hist(vx, bins=100, density=True)
plt.xlabel('vx [km/s]')
plt.ylabel('PDF')
plt.xlim(-40000, 40000)
plt.subplot(132)
plt.hist(vy, bins=100, density=True)
plt.xlabel('vy [km/s]')
plt.subplot(133)
plt.hist(vz, bins=100, density=True)
plt.xlabel('vz [km/s]')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

num_bins_x = 40
num_bins_z = 40 

# Example: x, z, v_y are 1D arrays of particle positions and velocities
# Define bin edges
x_bins = np.linspace(x.min(), x.max(), num_bins_x + 1)
z_bins = np.linspace(z.min(), z.max(), num_bins_z + 1)

# Digitize positions to bin indices
x_idx = np.digitize(x, x_bins) - 1
z_idx = np.digitize(z, z_bins) - 1

# Initialize array for mean v_y
mean_vy = np.full((num_bins_x, num_bins_z), np.nan)

# Calculate mean v_y for each bin
for i in range(num_bins_x):
    for j in range(num_bins_z):
        mask = (x_idx == i) & (z_idx == j)
        if np.any(mask):
            mean_vy[i, j] = np.mean(vy[mask])

# Plot with imshow
plt.imshow(mean_vy.T, origin='lower', aspect='auto',
           extent=[x_bins[0], x_bins[-1], z_bins[0], z_bins[-1]],
           cmap='RdBu')#, vmin = np.percentile(mean_vy, 0.001), vmax = np.percentile(mean_vy, 99.999))
plt.xlabel('x')
plt.ylabel('z')
plt.title('Mean $v_y$ (Line-of-Sight Velocity)')
plt.colorbar(label='Mean $v_y$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 25
#      23         mask = (x_idx == i) & (z_idx == j)
#      24         if np.any(mask):
# ---> 25             mean_vy[i, j] = np.mean(vy[mask])
#      27 # Plot with imshow
#      28 plt.imshow(mean_vy.T, origin='lower', aspect='auto',
#      29            extent=[x_bins[0], x_bins[-1], z_bins[0], z_bins[-1]],
#      30            cmap='RdBu')#, vmin = np.percentile(mean_vy, 0.001), vmax = np.percentile(mean_vy, 99.999))
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/array.py:386, in ArrayImpl.__getitem__(self, idx)
#     381       out = lax.squeeze(out, dimensions=dims)
#     383     return ArrayImpl(
#     384         out.aval, sharding, [out], committed=False, _skip_checks=True)
# --> 386 return indexing.rewriting_take(self, idx)
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/numpy/indexing.py:665, in rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value, normalize_indices, out_sharding)
#     661   out_sharding = canonicalize_sharding(out_sharding, 'take')
#     662   return auto_axes(internal_gather, out_sharding=out_sharding,
#     663                    axes=out_sharding.mesh.explicit_axes,  # type: ignore
#     664                    )(arr, dynamic_idx)
# --> 665 return internal_gather(arr, dynamic_idx)
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/numpy/indexing.py:674, in _gather(arr, dynamic_idx, treedef, static_idx, indices_are_sorted, unique_indices, mode, fill_value, normalize_indices)
#     671 def _gather(arr, dynamic_idx, *, treedef, static_idx, indices_are_sorted,
#     672             unique_indices, mode, fill_value, normalize_indices):
#     673   idx = merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# --> 674   indexer = index_to_gather(
#     675       np.shape(arr), idx, core.typeof(arr).sharding,
#     676       normalize_indices=normalize_indices)  # shared with _scatter_update
#     677   jnp_error._check_precondition_oob_gather(arr.shape, indexer.gather_indices)
#     678   y = arr
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/numpy/indexing.py:899, in index_to_gather(x_shape, idx, x_sharding, normalize_indices)
#     892 for idx_pos, i in enumerate(idx):
#     893   # Handle the advanced indices here if:
#     894   # * the advanced indices were not contiguous and we are the start.
#     895   # * we are at the position of the first advanced index.
#     896   if (advanced_indexes is not None and
#     897       (advanced_axes_are_contiguous and idx_pos == idx_advanced_axes[0] or
#     898        not advanced_axes_are_contiguous and idx_pos == 0)):
# --> 899     advanced_index_arrs = util._broadcast_arrays(*advanced_indexes)
#     900     shape = advanced_index_arrs[0].shape
#     901     aia_spec = core.typeof(advanced_index_arrs[0]).sharding.spec
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:268, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     263 if config.no_tracing.value:
#     264   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     265                      "`jit`, but 'no_tracing' is set")
#     267 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 268  executable, pgle_profiler, const_args) = _python_pjit_helper(
#     269      fun, jit_info, *args, **kwargs)
#     271 maybe_fastpath_data = _get_fastpath_data(
#     272     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     273     jit_info.abstracted_axes, pgle_profiler,
#     274     const_args)
#     276 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:147, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     145   args_flat = map(core.full_lower, args_flat)
#     146   core.check_eval_args(args_flat)
# --> 147   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     148       *args_flat, **p.params)
#     149 else:
#     150   out_flat = jit_p.bind(*args_flat, **p.params)
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:1748, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1745 compiler_options_kvs = compiler_options_kvs + tuple(pgle_compile_options.items())
#    1746 # Passing mutable PGLE profile here since it should be extracted by JAXPR to
#    1747 # initialize the fdo_profile compile option.
# -> 1748 computation = _resolve_and_lower(
#    1749     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1750     out_shardings=out_shardings, in_layouts=in_layouts,
#    1751     out_layouts=out_layouts, donated_invars=donated_invars,
#    1752     ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1753     inline=inline, lowering_platforms=None,
#    1754     lowering_parameters=mlir.LoweringParameters(),
#    1755     pgle_profiler=pgle_profiler,
#    1756     compiler_options_kvs=compiler_options_kvs,
#    1757 )
#    1758 compiled = computation.compile()
#    1760 # This check is expensive so only do it if enable_checks is on.
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:1712, in _resolve_and_lower(args, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, lowering_platforms, lowering_parameters, pgle_profiler, compiler_options_kvs)
#    1709 in_layouts = _resolve_in_layouts(args, in_layouts, in_shardings,
#    1710                                  jaxpr.in_avals)
#    1711 out_layouts = _resolve_out_layouts(out_layouts, out_shardings, jaxpr.out_avals)
# -> 1712 return _pjit_lower(
#    1713     jaxpr, in_shardings, out_shardings, in_layouts, out_layouts,
#    1714     donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs,
#    1715     lowering_platforms=lowering_platforms,
#    1716     lowering_parameters=lowering_parameters,
#    1717     pgle_profiler=pgle_profiler)
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:1854, in _pjit_lower(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, lowering_platforms, lowering_parameters, pgle_profiler)
#    1837 @weakref_lru_cache
#    1838 def _pjit_lower(
#    1839     jaxpr: core.ClosedJaxpr,
#    (...)   1852     lowering_parameters: mlir.LoweringParameters,
#    1853     pgle_profiler: profiler.PGLEProfiler | None) -> pxla.MeshComputation:
# -> 1854   return pxla.lower_sharding_computation(
#    1855       jaxpr, 'jit', name, in_shardings, out_shardings,
#    1856       in_layouts, out_layouts, tuple(donated_invars),
#    1857       keep_unused=keep_unused, context_mesh=ctx_mesh,
#    1858       compiler_options_kvs=compiler_options_kvs,
#    1859       lowering_platforms=lowering_platforms,
#    1860       lowering_parameters=lowering_parameters,
#    1861       pgle_profiler=pgle_profiler)
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/profiler.py:364, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     361 @wraps(func)
#     362 def wrapper(*args, **kwargs):
#     363   with TraceAnnotation(name, **decorator_kwargs):
# --> 364     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2421, in lower_sharding_computation(closed_jaxpr, api_name, fun_name, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, keep_unused, context_mesh, compiler_options_kvs, lowering_platforms, lowering_parameters, pgle_profiler)
#    2417 jaxpr_util.maybe_dump_jaxpr_to_file(fun_name, closed_jaxpr.jaxpr)
#    2418 module_name = util.wrap_name(api_name, fun_name)
#    2420 (module, keepalive, host_callbacks, unordered_effects, ordered_effects,
# -> 2421  nreps, tuple_args, shape_poly_state) = _cached_lowering_to_hlo(
#    2422      closed_jaxpr, module_name, backend,
#    2423      len(const_args), tuple(global_in_avals),
#    2424      semantic_in_shardings, semantic_out_shardings,
#    2425      in_layouts, out_layouts, num_devices,
#    2426      tuple(device_list) if prim_requires_devices else None,  # type: ignore[arg-type]
#    2427      donated_invars, all_default_mem_kind, inout_aliases,
#    2428      propagated_out_mem_kinds, platforms,
#    2429      lowering_parameters=lowering_parameters,
#    2430      abstract_mesh=abstract_mesh)
#    2432 # backend and device_assignment is passed through to MeshExecutable because
#    2433 # if keep_unused=False and all in_shardings are pruned, then there is no way
#    2434 # to get the device_assignment and backend. So pass it to MeshExecutable
#    2435 # because we calculate the device_assignment and backend before in_shardings,
#    2436 # etc are pruned.
#    2437 return MeshComputation(
#    2438     module_name,
#    2439     module,
#    (...)   2467     intermediate_shardings=unique_intermediate_shardings,
#    2468     context_mesh=context_mesh)
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1986, in _cached_lowering_to_hlo(closed_jaxpr, module_name, backend, num_const_args, in_avals, semantic_in_shardings, semantic_out_shardings, in_layouts, out_layouts, num_devices, device_assignment, donated_invars, all_default_mem_kind, inout_aliases, propagated_out_mem_kinds, platforms, lowering_parameters, abstract_mesh)
#    1982 arg_names = ("",) * num_const_args + jaxpr._debug_info.safe_arg_names(len(in_avals) - num_const_args)
#    1983 with dispatch.log_elapsed_time(
#    1984       "Finished jaxpr to MLIR module conversion {fun_name} in {elapsed_time:.9f} sec",
#    1985       fun_name=module_name, event=dispatch.JAXPR_TO_MLIR_MODULE_EVENT):
# -> 1986   lowering_result = mlir.lower_jaxpr_to_module(
#    1987       module_name,
#    1988       closed_jaxpr,
#    1989       num_const_args=num_const_args,
#    1990       ordered_effects=ordered_effects,
#    1991       backend=backend,
#    1992       platforms=platforms,
#    1993       axis_context=axis_ctx,
#    1994       in_avals=in_avals,
#    1995       donated_args=donated_invars,
#    1996       replicated_args=replicated_args,
#    1997       arg_shardings=in_mlir_shardings,
#    1998       result_shardings=out_mlir_shardings,
#    1999       in_layouts=in_layouts,
#    2000       out_layouts=out_layouts,
#    2001       arg_names=arg_names,
#    2002       result_names=jaxpr._debug_info.safe_result_paths(len(out_avals)),
#    2003       num_replicas=nreps,
#    2004       num_partitions=num_partitions,
#    2005       all_default_mem_kind=all_default_mem_kind,
#    2006       input_output_aliases=inout_aliases,
#    2007       propagated_out_mem_kinds=propagated_out_mem_kinds,
#    2008       lowering_parameters=lowering_parameters)
#    2009 tuple_args = dispatch.should_tuple_args(len(in_avals), backend.platform)
#    2010 unordered_effects = list(
#    2011     effects.ordered_effects.filter_not_in(closed_jaxpr.effects))
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1375, in lower_jaxpr_to_module(***failed resolving arguments***)
#    1373   attrs["mhlo.num_replicas"] = i32_attr(num_replicas)
#    1374   attrs["mhlo.num_partitions"] = i32_attr(num_partitions)
# -> 1375   lower_jaxpr_to_fun(
#    1376       ctx, module_name, jaxpr, ordered_effects,
#    1377       num_const_args=num_const_args,
#    1378       main_function=True,
#    1379       replicated_args=replicated_args,
#    1380       in_avals=in_avals,
#    1381       arg_shardings=arg_shardings,
#    1382       result_shardings=result_shardings,
#    1383       input_output_aliases=input_output_aliases,
#    1384       xla_donated_args=xla_donated_args,
#    1385       arg_names=arg_names,
#    1386       result_names=result_names,
#    1387       arg_memory_kinds=arg_memory_kinds,
#    1388       result_memory_kinds=result_memory_kinds,
#    1389       arg_layouts=in_layouts,
#    1390       result_layouts=out_layouts,
#    1391       propagated_out_mem_kinds=propagated_out_mem_kinds)
#    1393 try:
#    1394   if not ctx.module.operation.verify():
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1863, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, num_const_args, main_function, replicated_args, in_avals, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts, propagated_out_mem_kinds)
#    1861   for n in arg_names:
#    1862     arg_locs.append(ir.Location.name(n) if n else ir.Location.unknown())
# -> 1863   entry_block = func_op.add_entry_block(arg_locs)
#    1864 else:
#    1865   with ir.Location.unknown():
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jaxlib/mlir/dialects/func.py:103, in FuncOp.add_entry_block(self, arg_locs)
#     101 if not self.is_external:
#     102     raise IndexError("The function already has an entry block!")
# --> 103 self.body.blocks.append(*self.type.inputs, arg_locs=arg_locs)
#     104 return self.body.blocks[0]
#
# File ~/miniconda3/envs/phoenix/lib/python3.12/site-packages/jaxlib/mlir/dialects/func.py:79, in FuncOp.type(self)
#      77 @property
#      78 def type(self):
# ---> 79     return FunctionType(TypeAttr(self.attributes["function_type"]).value)
#
# KeyboardInterrupt:

# %%
# Plot mean line-of-sight velocity (mean vx) in the yz-plane
num_bins_y = 40
num_bins_z = 40

y_bins = np.linspace(y.min(), y.max(), num_bins_y + 1)
z_bins = np.linspace(z.min(), z.max(), num_bins_z + 1)

y_idx = np.digitize(y, y_bins) - 1
z_idx = np.digitize(z, z_bins) - 1

mean_vx = np.full((num_bins_y, num_bins_z), np.nan)

for i in range(num_bins_y):
    for j in range(num_bins_z):
        mask = (y_idx == i) & (z_idx == j)
        if np.any(mask):
            mean_vx[i, j] = np.mean(vx[mask])

plt.figure(figsize=(7, 6))
plt.imshow(mean_vx.T, origin='lower', aspect='auto',
           extent=[y_bins[0], y_bins[-1], z_bins[0], z_bins[-1]],
           cmap='RdBu')
plt.xlabel('y')
plt.ylabel('z')
plt.title('Mean $v_x$ (Line-of-Sight Velocity) in yz-plane')
plt.colorbar(label='Mean $v_x$')
plt.show()

# %%
# Plot mean line-of-sight velocity (mean vz) in the xy-plane
num_bins_x = 40
num_bins_y = 40

x_bins = np.linspace(x.min(), x.max(), num_bins_x + 1)
y_bins = np.linspace(y.min(), y.max(), num_bins_y + 1)

x_idx = np.digitize(x, x_bins) - 1
y_idx = np.digitize(y, y_bins) - 1

mean_vz = np.full((num_bins_x, num_bins_y), np.nan)

for i in range(num_bins_x):
    for j in range(num_bins_y):
        mask = (x_idx == i) & (y_idx == j)
        if np.any(mask):
            mean_vz[i, j] = np.mean(vz[mask])

plt.figure(figsize=(7, 6))
plt.imshow(mean_vz.T, origin='lower', aspect='auto',
           extent=[x_bins[0], x_bins[-1], y_bins[0], y_bins[-1]],
           cmap='RdBu')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Mean $v_z$ (Line-of-Sight Velocity) in xy-plane')
plt.colorbar(label='Mean $v_z$')
plt.show()
