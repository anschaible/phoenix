# %%
from phoenix import distributionfunction, sampling, actions_to_phase_space
from phoenix.potentials import miyamoto_nagai_potential, plummer_potential
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
# Out:
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:10: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:38: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:44: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:50: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:56: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:86: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:114: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:119: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:125: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:131: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:138: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:172: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_disky_Binney.py:185: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped
# /home/annalena/phoenix/phoenix/distributionfunctions_spheroidal.py:10: UserWarning: As of jaxtyping version 0.2.24, jaxtyping now prefers the syntax
# ```
# from jaxtyping import jaxtyped
# # Use your favourite typechecker: usually one of the two lines below.
# from typeguard import typechecked as typechecker
# from beartype import beartype as typechecker
#
# @jaxtyped(typechecker=typechecker)
# def foo(...):
# ```
# and the old double-decorator syntax
# ```
# @jaxtyped
# @typechecker
# def foo(...):
# ```
# should no longer be used. (It will continue to work as it did before, but the new approach will produce more readable error messages.)
# In particular note that `typechecker` must be passed via keyword argument; the following is not valid:
# ```
# @jaxtyped(typechecker)
# def foo(...):
# ```
#
#   @jaxtyped

# %%
params = {
    "R0": 8.0, # for actions to phase space
    "N0_spheroid": 1e6,
    "J0_spheroid": 50.0,
    "Gamma_spheroid": 2.5,
    "Beta_spheroid": 3.5,
}

envelope_max = 3.0
n_candidates = 250_000
key = jax.random.PRNGKey(42)
# Js are max 400, 400, 2000

Phi_spheroid = plummer_potential
theta_spheroid = jnp.array([1e12, 20.0]) # (M, a) z.B. für Plummer

# %%
#Generate candidate actions
from phoenix.distributionfunctions_spheroidal import f_double_power_law as df_spheroid
candidates, samples, soft_weights = sampling.sample_df_potential(df_spheroid, key, params, Phi_spheroid, theta_spheroid, n_candidates, envelope_max, tau=0.01)
print("Number of candidate actions:", samples.shape[0])

#Map the candidate actions to phase-space coordinates
phase_space_coords = actions_to_phase_space.map_actions_to_phase_space(candidates, params, key, Phi_spheroid, theta_spheroid)
x = phase_space_coords[:, 0]
y = phase_space_coords[:, 1]
z = phase_space_coords[:, 2]
v_x = phase_space_coords[:, 3]
v_y = phase_space_coords[:, 4]
v_z = phase_space_coords[:, 5]
# Out:
# Number of candidate actions: 250000

# %%
#Visualize the distribution of candidate actions
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
axs[0].hist(samples[:, 0], bins=50, weights=soft_weights)
axs[0].set_xlabel(r"$J_r$")
axs[1].hist(samples[:, 1], bins=50, weights=soft_weights)
axs[1].set_xlabel(r"$J_z$")
axs[2].hist(samples[:, 2], bins=50, weights=soft_weights)
axs[2].set_xlabel(r"$L_z$")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
plt.figure(figsize=(12,6))
plt.subplot(231)
plt.hist2d(x, y, bins=50, cmap="viridis", norm=colors.LogNorm(), weights=soft_weights)
plt.xlabel('x [kpc]')
plt.ylabel('y [kpc]')
plt.axis('equal')
plt.subplot(232)
plt.hist2d(x, z, bins=50, cmap="viridis", norm=colors.LogNorm(), weights=soft_weights)
plt.xlabel('x [kpc]')
plt.ylabel('z [kpc]')
plt.axis('equal')
plt.subplot(233)
plt.hist2d(y, z, bins=50, cmap="viridis", norm=colors.LogNorm(), weights=soft_weights)
plt.xlabel('y [kpc]')
plt.ylabel('z [kpc]')
plt.axis('equal')

plt.subplot(234)
plt.hist(v_x, bins=50, weights=soft_weights)#, range=(-2000, 2000))
plt.xlabel(r"$v_\text{x}$ (km/s)")
plt.ylabel("Number of stars")

plt.subplot(235)
plt.hist(v_y, bins=50, weights=soft_weights)#, range=(-2000, 2000))
plt.xlabel(r"$v_\text{y}$ (km/s)")
plt.ylabel("Number of stars")

plt.subplot(236)
plt.hist(v_z, bins=50, weights=soft_weights)
plt.xlabel(r"$v_\text{z}$ (km/s)")
plt.ylabel("Number of stars")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from scipy.stats import binned_statistic_2d

# Helper function to calculate weighted mean
def weighted_mean_2d(x_pos, y_pos, values, weights, x_bins, y_bins):
    # Sum of (value * weight) in each bin
    weighted_sum, _, _, _ = binned_statistic_2d(
        x_pos, y_pos, values * weights, statistic='sum', bins=[x_bins, y_bins]
    )
    # Sum of weights in each bin
    sum_of_weights, _, _, _ = binned_statistic_2d(
        x_pos, y_pos, weights, statistic='sum', bins=[x_bins, y_bins]
    )
    
    # Divide, handling division by zero (where sum_of_weights is 0)
    with np.errstate(divide='ignore', invalid='ignore'):
        result = weighted_sum / sum_of_weights
    
    return result

num_bins_x = 40
num_bins_y = 40
num_bins_z = 40 

# Example: x, z, v_y are 1D arrays of particle positions and velocities
# Define bin edges
x_bins = np.linspace(x.min(), x.max(), num_bins_x + 1)
y_bins = np.linspace(y.min(), y.max(), num_bins_x + 1)
z_bins = np.linspace(z.min(), z.max(), num_bins_z + 1)

# Digitize positions to bin indices
x_idx = np.digitize(x, x_bins) - 1
y_idx = np.digitize(y, y_bins) - 1
z_idx = np.digitize(z, z_bins) - 1

# Initialize array for mean v_y
mean_vx = np.full((num_bins_y, num_bins_z), np.nan)
mean_vy = np.full((num_bins_x, num_bins_z), np.nan)
mean_vz = np.full((num_bins_x, num_bins_y), np.nan)

# 1. Mean v_x (y vs z)
mean_vx = weighted_mean_2d(y, z, v_x, soft_weights, y_bins, z_bins)

# 2. Mean v_y (x vs z)
mean_vy = weighted_mean_2d(x, z, v_y, soft_weights, x_bins, z_bins)

# 3. Mean v_z (x vs y)
mean_vz = weighted_mean_2d(x, y, v_z, soft_weights, x_bins, y_bins)

        
# Plot mean velocity maps side-by-side (y vs z, x vs z, x vs y)
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
# mean_vx: y vs z
im0 = axs[0].imshow(mean_vx.T, origin='lower', aspect='auto',
                   extent=[y_bins[0], y_bins[-1], z_bins[0], z_bins[-1]],
                   cmap='RdBu')
axs[0].set_xlabel('y')
axs[0].set_ylabel('z')
axs[0].set_title('Mean $v_x$ (y vs z)')
axs[0].axis('equal')
plt.colorbar(im0, ax=axs[0], label='Mean $v_x$')
# mean_vy: x vs z
im1 = axs[1].imshow(mean_vy.T, origin='lower', aspect='auto',
                   extent=[x_bins[0], x_bins[-1], z_bins[0], z_bins[-1]],
                   cmap='RdBu')
axs[1].set_xlabel('x')
axs[1].set_ylabel('z')
axs[1].set_title('Mean $v_y$ (x vs z)')
axs[1].axis('equal')
plt.colorbar(im1, ax=axs[1], label='Mean $v_y$')
# mean_vz: x vs y
im2 = axs[2].imshow(mean_vz.T, origin='lower', aspect='auto',
                   extent=[x_bins[0], x_bins[-1], y_bins[0], y_bins[-1]],
                   cmap='RdBu')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')
axs[2].set_title('Mean $v_z$ (x vs y)')
plt.colorbar(im2, ax=axs[2], label='Mean $v_z$')
axs[2].axis('equal')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

num_bins_x = 40
num_bins_y = 40
num_bins_z = 40 

# Example: x, z, v_y are 1D arrays of particle positions and velocities
# Define bin edges
x_bins = np.linspace(x.min(), x.max(), num_bins_x + 1)
y_bins = np.linspace(y.min(), y.max(), num_bins_x + 1)
z_bins = np.linspace(z.min(), z.max(), num_bins_z + 1)

# Digitize positions to bin indices
x_idx = np.digitize(x, x_bins) - 1
y_idx = np.digitize(y, y_bins) - 1
z_idx = np.digitize(z, z_bins) - 1

# Initialize array for mean v_y
mean_vx = np.full((num_bins_y, num_bins_z), np.nan)
mean_vy = np.full((num_bins_x, num_bins_z), np.nan)
mean_vz = np.full((num_bins_x, num_bins_y), np.nan)

# Calculate mean v_x for each bin
for i in range(num_bins_y):
    for j in range(num_bins_z):
        mask = (y_idx == i) & (z_idx == j)
        current_weights = soft_weights[mask]
        # Check if mask is not empty AND weights sum to > 0
        if np.any(mask) and np.sum(current_weights) > 0:
            mean_vx[i, j] = np.average(v_x[mask], weights=current_weights)

# Calculate mean v_y for each bin
for i in range(num_bins_x):
    for j in range(num_bins_z):
        mask = (x_idx == i) & (z_idx == j)
        current_weights = soft_weights[mask]
        if np.any(mask) and np.sum(current_weights) > 0:
            mean_vy[i, j] = np.average(v_y[mask], weights=current_weights)

# Calculate mean v_z for each bin
for i in range(num_bins_x):
    for j in range(num_bins_y):
        mask = (x_idx == i) & (y_idx == j)
        current_weights = soft_weights[mask]
        if np.any(mask) and np.sum(current_weights) > 0:
            mean_vz[i, j] = np.average(v_z[mask], weights=current_weights)

        
# Plot mean velocity maps side-by-side (y vs z, x vs z, x vs y)
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
# mean_vx: y vs z
im0 = axs[0].imshow(mean_vx.T, origin='lower', aspect='auto',
                   extent=[y_bins[0], y_bins[-1], z_bins[0], z_bins[-1]],
                   cmap='RdBu')
axs[0].set_xlabel('y')
axs[0].set_ylabel('z')
axs[0].set_title('Mean $v_x$ (y vs z)')
axs[0].axis('equal')
plt.colorbar(im0, ax=axs[0], label='Mean $v_x$')
# mean_vy: x vs z
im1 = axs[1].imshow(mean_vy.T, origin='lower', aspect='auto',
                   extent=[x_bins[0], x_bins[-1], z_bins[0], z_bins[-1]],
                   cmap='RdBu')
axs[1].set_xlabel('x')
axs[1].set_ylabel('z')
axs[1].set_title('Mean $v_y$ (x vs z)')
axs[1].axis('equal')
plt.colorbar(im1, ax=axs[1], label='Mean $v_y$')
# mean_vz: x vs y
im2 = axs[2].imshow(mean_vz.T, origin='lower', aspect='auto',
                   extent=[x_bins[0], x_bins[-1], y_bins[0], y_bins[-1]],
                   cmap='RdBu')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')
axs[2].set_title('Mean $v_z$ (x vs y)')
plt.colorbar(im2, ax=axs[2], label='Mean $v_z$')
axs[2].axis('equal')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 29
#      27 for j in range(num_bins_z):
#      28     mask = (y_idx == i) & (z_idx == j)
# ---> 29     current_weights = soft_weights[mask]
#      30     # Check if mask is not empty AND weights sum to > 0
#      31     if np.any(mask) and np.sum(current_weights) > 0:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/array.py:374, in ArrayImpl.__getitem__(self, idx)
#     369       out = lax.squeeze(out, dimensions=dims)
#     371     return ArrayImpl(
#     372         out.aval, sharding, [out], committed=False, _skip_checks=True)
# --> 374 return indexing.rewriting_take(self, idx)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/numpy/indexing.py:666, in rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value, normalize_indices, out_sharding)
#     662   out_sharding = canonicalize_sharding(out_sharding, 'take')
#     663   return auto_axes(internal_gather, out_sharding=out_sharding,
#     664                    axes=out_sharding.mesh.explicit_axes,  # type: ignore
#     665                    )(arr, dynamic_idx)
# --> 666 return internal_gather(arr, dynamic_idx)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/numpy/indexing.py:675, in _gather(arr, dynamic_idx, treedef, static_idx, indices_are_sorted, unique_indices, mode, fill_value, normalize_indices)
#     672 def _gather(arr, dynamic_idx, *, treedef, static_idx, indices_are_sorted,
#     673             unique_indices, mode, fill_value, normalize_indices):
#     674   idx = merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# --> 675   indexer = index_to_gather(
#     676       np.shape(arr), idx, core.typeof(arr).sharding,
#     677       normalize_indices=normalize_indices)  # shared with _scatter_update
#     678   jnp_error._check_precondition_oob_gather(arr.shape, indexer.gather_indices)
#     679   y = arr
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/numpy/indexing.py:860, in index_to_gather(x_shape, idx, x_sharding, normalize_indices)
#     857   if normalize_indices:
#     858     advanced_pairs = ((_normalize_index(e, x_shape[j]), i, j)
#     859                       for e, i, j in advanced_pairs)
# --> 860   advanced_indexes, idx_advanced_axes, x_advanced_axes = zip(*advanced_pairs)
#     862 x_axis = 0  # Current axis in x.
#     863 y_axis = 0  # Current axis in y, before collapsing. See below.
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/numpy/indexing.py:858, in <genexpr>(.0)
#     852   advanced_pairs = (
#     853     (lax_numpy.asarray(e), i, j) for j, (i, e) in enumerate(idx_no_nones)
#     854     if lax_numpy.isscalar(e)
#     855     or isinstance(e, (Sequence, Array, np.ndarray,
#     856                       literals.TypedNdArray)))
#     857   if normalize_indices:
# --> 858     advanced_pairs = ((_normalize_index(e, x_shape[j]), i, j)
#     859                       for e, i, j in advanced_pairs)
#     860   advanced_indexes, idx_advanced_axes, x_advanced_axes = zip(*advanced_pairs)
#     862 x_axis = 0  # Current axis in x.
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/numpy/indexing.py:204, in _normalize_index(index, axis_size)
#     202   return lax.add(index, axis_size_val) if index < 0 else index
#     203 else:
# --> 204   return lax.select(index < 0, lax.add(index, axis_size_val), index)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/lax/lax.py:1198, in add(x, y)
#    1178 r"""Elementwise addition: :math:`x + y`.
#    1179
#    1180 This function lowers directly to the `stablehlo.add`_ operation.
#    (...)   1195 .. _stablehlo.add: https://openxla.org/stablehlo/spec#add
#    1196 """
#    1197 x, y = core.standard_insert_pvary(x, y)
# -> 1198 return add_p.bind(x, y)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:632, in Primitive.bind(self, *args, **params)
#     630 def bind(self, *args, **params):
#     631   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 632   return self._true_bind(*args, **params)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:648, in Primitive._true_bind(self, *args, **params)
#     646 trace_ctx.set_trace(eval_trace)
#     647 try:
# --> 648   return self.bind_with_trace(prev_trace, args, params)
#     649 finally:
#     650   trace_ctx.set_trace(prev_trace)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:660, in Primitive.bind_with_trace(self, trace, args, params)
#     658     with set_current_trace(trace):
#     659       return self.to_lojax(*args, **params)  # type: ignore
# --> 660   return trace.process_primitive(self, args, params)
#     661 trace.process_primitive(self, args, params)  # may raise lojax error
#     662 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/core.py:1189, in EvalTrace.process_primitive(self, primitive, args, params)
#    1187 args = map(full_lower, args)
#    1188 check_eval_args(args)
# -> 1189 return primitive.impl(*args, **params)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/dispatch.py:92, in apply_primitive(prim, *args, **params)
#      90 prev = config.disable_jit.swap_local(False)
#      91 try:
# ---> 92   outs = fun(*args)
#      93 finally:
#      94   config.disable_jit.set_local(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:264, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     259 if config.no_tracing.value:
#     260   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     261                      "`jit`, but 'no_tracing' is set")
#     263 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 264  executable, pgle_profiler, const_args) = _python_pjit_helper(
#     265      fun, jit_info, *args, **kwargs)
#     267 maybe_fastpath_data = _get_fastpath_data(
#     268     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     269     jit_info.abstracted_axes, pgle_profiler,
#     270     const_args)
#     272 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:146, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     144   args_flat = map(core.full_lower, args_flat)
#     145   core.check_eval_args(args_flat)
# --> 146   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     147       *args_flat, **p.params)
#     148 else:
#     149   out_flat = jit_p.bind(*args_flat, **p.params)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/pjit.py:1620, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1609 arg_types = map(convert_to_metaty, args)
#    1610 computation = _resolve_and_lower(
#    1611     arg_types, jaxpr=jaxpr, in_shardings=in_shardings,
#    1612     out_shardings=out_shardings, in_layouts=in_layouts,
#    (...)   1618     compiler_options_kvs=compiler_options_kvs,
#    1619 )
# -> 1620 compiled = computation.compile()
#    1622 # This check is expensive so only do it if enable_checks is on.
#    1623 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2527, in MeshComputation.compile(self, compiler_options, device_assignment)
#    2524 assert isinstance(compilation_device_list, (type(None), xc.DeviceList))
#    2526 if self._executable is None or compiler_options_kvs or device_assignment:
# -> 2527   executable = UnloadedMeshExecutable.from_hlo(
#    2528       self._name, self._hlo, **self.compile_args,
#    2529       compiler_options_kvs=compiler_options_kvs,
#    2530       device_list=compilation_device_list)
#    2531   if not compiler_options_kvs:
#    2532     self._executable = executable
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:3073, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    3070       break
#    3072 util.test_event("pxla_cached_compilation")
# -> 3073 xla_executable = _cached_compilation(
#    3074     hlo, name, mesh, spmd_lowering,
#    3075     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    3076     allow_prop_to_outputs, tuple(host_callbacks), backend, device_list,
#    3077     pmap_nreps, compiler_options_kvs, pgle_profiler)
#    3079 if auto_spmd_lowering:
#    3080   assert mesh is not None
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2854, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2846 compile_options = create_compile_options(
#    2847     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2848     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2849     dev, pmap_nreps, compiler_options)
#    2851 with dispatch.log_elapsed_time(
#    2852     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2853     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2854   xla_executable = compiler.compile_or_get_cached(
#    2855       backend, computation, dev, compile_options, host_callbacks,
#    2856       da, pgle_profiler)
#    2857 return xla_executable
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/compiler.py:478, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, executable_devices, pgle_profiler)
#     476 else:
#     477   log_persistent_cache_miss(module_name, cache_key)
# --> 478   return _compile_and_write_cache(
#     479       backend,
#     480       computation,
#     481       executable_devices,
#     482       compile_options,
#     483       host_callbacks,
#     484       module_name,
#     485       cache_key,
#     486   )
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/compiler.py:746, in _compile_and_write_cache(backend, computation, executable_devices, compile_options, host_callbacks, module_name, cache_key)
#     736 def _compile_and_write_cache(
#     737     backend: xc.Client,
#     738     computation: ir.Module,
#    (...)    743     cache_key: str,
#     744 ) -> xc.LoadedExecutable:
#     745   start_time = time.monotonic()
# --> 746   executable = backend_compile_and_load(
#     747       backend, computation, executable_devices, compile_options, host_callbacks
#     748   )
#     749   compile_time = time.monotonic() - start_time
#     750   _cache_write(
#     751       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     752   )
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/profiler.py:359, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     356 @wraps(func)
#     357 def wrapper(*args, **kwargs):
#     358   with TraceAnnotation(name, **decorator_kwargs):
# --> 359     return func(*args, **kwargs)
#
# File ~/.conda/envs/phoenix/lib/python3.12/site-packages/jax/_src/compiler.py:362, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     353       return backend.compile_and_load(
#     354           module,
#     355           executable_devices=executable_devices,
#     356           compile_options=options,
#     357           host_callbacks=host_callbacks,
#     358       )
#     359     # Some backends don't have `host_callbacks` option yet
#     360     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     361     # to take in `host_callbacks`
# --> 362     return backend.compile_and_load(
#     363         module,
#     364         executable_devices=executable_devices,
#     365         compile_options=options,
#     366     )
#     367 except _jax.JaxRuntimeError as e:
#     368   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:
